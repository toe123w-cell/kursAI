# %% [markdown]
# <a href="https://colab.research.google.com/github/toe123w-cell/kursAI/blob/main/wprowadzenie_do_%C5%9Brodowiska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # podstawy pythona
#
# 1.   Zmienne
# 2.   Listy
# 3.   Pętle
# 4.   Słowniki i krotki
# 5.   Instrukcje warunkowe
# 6.   Funkcje
# 7.   Obsługa plików
# 8.   Obsługa wyjątków

# %%
# !git init
# !git config --global user.name "toe123w-cell"
# !git config --global user.email "toe123w@gmail.com"

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "incjalizacja projektu"

# %%
# !git branch -M main

# %%
# !git push -u origin main

# %% [markdown]
# # Zmienne

# %%
calkowita = 5
zmiennoprzecinkowa = 3.6
napis = 'tekst'
logiczna = True

print(f'calkowita: {calkowita}, zmiennoprzecinkowa: {zmiennoprzecinkowa}, napis: {napis}, logiczna:{logiczna}')
# Out:
# calkowita: 5, zmiennoprzecinkowa: 3.6, napis: tekst, logiczna:True

# %% [markdown]
# # Listy

# %%
ksiazki = ['popularno naukowa', 'fantasy', 'sci fi']
lista_mieszana = [1, 'jakis napis', ksiazki]
print(ksiazki)
print(lista_mieszana)
print(ksiazki[1])

# %% [markdown]
# # Pętle

# %%
licznik = 0

while licznik < 5:
  print(licznik)
  licznik += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Słowniki i krotki

# %% [markdown]
# # Instrukcje warunkowe

# %%
temperatura = float(input("Podaj temperaturę: "))

if temperatura < 20:
  print("Podwyższam temperaturę")
elif temperatura >25:
  print("Obniżam temperaturę")
else:
  print("Temperatura w normie")

# %% [markdown]
# # Funkcje

# %% [markdown]
# # Obsługa plików

# %% [markdown]
# # Obsługa wyjątków

# %%
# !git add .
# !git commit -m "ukończono wprowadzenie"
# !git push origin main
